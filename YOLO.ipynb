# %% [markdown]
# <a href="https://colab.research.google.com/github/amritanshh/CleanSight/blob/main/YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5

# Install required dependencies
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17581, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 17581 (delta 40), reused 12 (delta 10), pack-reused 17510 (from 3)
# Receiving objects: 100% (17581/17581), 16.66 MiB | 20.65 MiB/s, done.
# Resolving deltas: 100% (12042/12042), done.
# /content/yolov5/yolov5
# ...

# %%
# Check Python and PyTorch versions
import torch, torchvision
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

# Quick repo structure check
# !ls
# Out:
# Torch version: 2.8.0+cu126
# CUDA available: False
# benchmarks.py	 data	     LICENSE	     README.zh-CN.md   tutorial.ipynb
# CITATION.cff	 detect.py   models	     requirements.txt  utils
# classify	 export.py   pyproject.toml  segment	       val.py
# CONTRIBUTING.md  hubconf.py  README.md	     train.py

# %%
# YOLOv5 comes with several pretrained models: small (s), medium (m), large (l), extra large (x)
# I use the samllest one to save time here
# !wget https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5s.pt
# Out:
# --2025-09-15 17:58:22--  https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5s.pt
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Run detection on sample images provided in repo (from COCO dataset)
# !python detect.py --source data/images --weights yolov5s.pt --conf 0.25
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# YOLOv5s_v6 summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 334.3ms
# image 2/2 /content/yolov5/yolov5/data/images/zidane.jpg: 384x640 2 persons, 1 tie, 262.5ms
# Speed: 2.0ms pre-process, 298.4ms inference, 2.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
import glob
from IPython.display import Image, display

# Show detected images
for img in glob.glob('runs/detect/exp/*.jpg'):
    display(Image(filename=img))

# %%
print("✅ Object detection demo completed!")
print("We successfully used YOLOv5 with COCO dataset pretrained weights.")
# Out:
# ✅ Object detection demo completed!
# We successfully used YOLOv5 with COCO dataset pretrained weights.
